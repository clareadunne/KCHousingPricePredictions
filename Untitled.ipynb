# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
import scipy.stats as st
warnings.filterwarnings("ignore") 
pd.set_option('display.max_columns', 360)

# %%
df = pd.read_csv('TotalSearchResults.csv')

# %%
homes = df[df['Living Area'] != 0]

# %%
homes['livarea'] = homes['Living Area']

homes
# Out:
#                                                    Url   Price Days On Zillow  \
# 0    https://www.zillow.com/homedetails/7259-Ann-St...   60000  Not specified
# 1    https://www.zillow.com/homedetails/6101-Poplar...  140000  Not specified
# 2    https://www.zillow.com/homedetails/2041-County...  330000  Not specified
# 3    https://www.zillow.com/homedetails/5681-State-...  675000  Not specified
# 4    https://www.zillow.com/homedetails/7508-State-...  135000  Not specified
# ..                                                 ...     ...            ...
# 208  https://www.zillow.com/homedetails/7157-Main-S...  250000  Not specified
# 209  https://www.zillow.com/homedetails/8324-Lower-...  105000  Not specified
# 210  https://www.zillow.com/homedetails/8766-Route-...    3000  Not specified
# 211  https://www.zillow.com/homedetails/7430-State-...   35000  Not specified
# 212  https://www.zillow.com/homedetails/7364-State-...   90000  Not specified
#
#      Bathrooms  Bedrooms  Living Area  Lot Size      Home Type  \
# 0          1.0       2.0       1136.0       NaN  SINGLE_FAMILY
# 1          2.5       3.0       2287.0       NaN  SINGLE_FAMILY
# 2          1.0       3.0       1270.0       NaN  SINGLE_FAMILY
# 3          2.0       3.0       1584.0       NaN  SINGLE_FAMILY
# 4          2.0       3.0       1150.0       NaN  SINGLE_FAMILY
# ..         ...       ...          ...       ...            ...
# 208        NaN       NaN       7464.0       NaN  SINGLE_FAMILY
# 209        1.0       3.0        816.0       NaN  SINGLE_FAMILY
# 210        1.5       5.0       2908.0       NaN  SINGLE_FAMILY
# 211        1.0       1.0        777.0       NaN  SINGLE_FAMILY
# 212        2.0       4.0       1776.0       NaN  SINGLE_FAMILY
#
#            Street Address     City    Zip State Country  livarea
# 0             7259 Ann St     Ovid  14521    NY     USA   1136.0
# 1         6101 Poplar Bch     Ovid  14541    NY     USA   2287.0
# 2    2041 County Road 139     Ovid  14521    NY     USA   1270.0
# 3     5681 State Route 89  Romulus  14541    NY     USA   1584.0
# 4    7508 State Route 414     Ovid  14521    NY     USA   1150.0
# ..                    ...      ...    ...   ...     ...      ...
# 208          7157 Main St     Ovid  14521    NY     USA   7464.0
# 209    8324 Lower Lake Rd     Lodi  14860    NY     USA    816.0
# 210        8766 Route 414     Ovid  14521    NY     USA   2908.0
# 211  7430 State Route 414     Ovid  14521    NY     USA    777.0
# 212   7364 State Route 96     Ovid  14521    NY     USA   1776.0
#
# [213 rows x 14 columns]

# %%
from statsmodels.formula.api import ols

ols(formula='Price~livarea', data=homes).fit().summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  Price   R-squared:                       0.066
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     12.36
# Date:                Wed, 02 Jun 2021   Prob (F-statistic):           0.000558
# Time:                        14:41:24   Log-Likelihood:                -2397.0
# No. Observations:                 178   AIC:                             4798.
# Df Residuals:                     176   BIC:                             4804.
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   1.032e+05   2.28e+04      4.529      0.000    5.82e+04    1.48e+05
# livarea       35.9066     10.213      3.516      0.001      15.751      56.063
# ==============================================================================
# Omnibus:                       92.648   Durbin-Watson:                   1.798
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              394.827
# Skew:                           2.046   Prob(JB):                     1.84e-86
# Kurtosis:                       9.041   Cond. No.                     3.95e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.95e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
